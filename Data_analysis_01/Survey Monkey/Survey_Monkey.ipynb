# %%
import pandas as pd
import os

# %%
pwd = os.getcwd()
print(pwd)
# Out:
# /Users/zll/Library/Mobile Documents/com~apple~CloudDocs/Python Data Science/Pandas_basic_Lv1/Survey Monkey

# %%
dataset = pd.read_excel(pwd + "/Data - Survey Monkey Output Edited.xlsx", sheet_name="Edited_Data")
dataset
# Out:
#      Respondent ID          Start Date            End Date  Email Address  \
# 0       5379192392 2021-01-22 12:01:17 2021-01-22 12:40:34            NaN
# 1       2658722536 2021-01-22 06:56:37 2021-01-22 07:34:10            NaN
# 2       4044163394 2021-01-22 06:35:18 2021-01-22 06:47:32            NaN
# 3       5535865599 2021-01-21 21:29:32 2021-01-21 21:40:24            NaN
# 4       3356802928 2021-01-21 17:26:39 2021-01-21 17:44:40            NaN
# ..             ...                 ...                 ...            ...
# 193     7940065082 2021-01-11 06:19:18 2021-01-11 06:32:59            NaN
# 194     5157705612 2021-01-11 06:19:14 2021-01-11 06:33:29            NaN
# 195     9920755555 2021-01-11 06:18:48 2021-01-11 06:27:27            NaN
# 196     6638341389 2021-01-11 06:19:01 2021-01-11 06:33:06            NaN
# 197     8114622230 2021-01-11 06:18:50 2021-01-11 06:26:46            NaN
#
#      First Name  Last Name  Custom Data 1  \
# ...

# %%
dataset_modified = dataset.copy()
dataset_modified
# Out:
#      Respondent ID          Start Date            End Date  Email Address  \
# 0       5379192392 2021-01-22 12:01:17 2021-01-22 12:40:34            NaN
# 1       2658722536 2021-01-22 06:56:37 2021-01-22 07:34:10            NaN
# 2       4044163394 2021-01-22 06:35:18 2021-01-22 06:47:32            NaN
# 3       5535865599 2021-01-21 21:29:32 2021-01-21 21:40:24            NaN
# 4       3356802928 2021-01-21 17:26:39 2021-01-21 17:44:40            NaN
# ..             ...                 ...                 ...            ...
# 193     7940065082 2021-01-11 06:19:18 2021-01-11 06:32:59            NaN
# 194     5157705612 2021-01-11 06:19:14 2021-01-11 06:33:29            NaN
# 195     9920755555 2021-01-11 06:18:48 2021-01-11 06:27:27            NaN
# 196     6638341389 2021-01-11 06:19:01 2021-01-11 06:33:06            NaN
# 197     8114622230 2021-01-11 06:18:50 2021-01-11 06:26:46            NaN
#
#      First Name  Last Name  Custom Data 1  \
# ...

# %%
list(dataset_modified.columns)
# Out:
# ['Respondent ID',
#  'Start Date',
#  'End Date',
#  'Email Address',
#  'First Name',
#  'Last Name',
#  'Custom Data 1',
#  'Identify which division you work in. - Response',
#  'Identify which division you work in. - Other (please specify)',
#  'Which of the following best describes your position level? - Response',
#  'Which generation are you apart of? - Response',
#  'Please select the gender in which you identify. - Response',
#  'Which duration range best aligns with your tenure at your company? - Response',
#  'Which of the following best describes your employment type? - Response',
#  'Question 1 - Response',
#  'Question 2 - Response',
#  'Question 3 - Open-Ended Response',
#  'Question 4 - Response',
#  'Question 4 - Other (please specify)',
#  'Question 5 - Response 1',
#  'Question 5 - Response 2',
#  'Question 5 - Response 3',
#  'Question 5 - Response 4',
#  'Question 5 - Response 5',
#  'Question 5 - Response 6',
#  'Question 6 - Response 1',
# ...

# %%
columns_to_drop = [
    'Start Date', 'End Date', 'Email Address', 'First Name', 'Last Name', 'Custom Data 1']
dataset_modified = dataset_modified.drop(columns=columns_to_drop)
dataset_modified
# Out:
#      Respondent ID Identify which division you work in. - Response  \
# 0       5379192392                                  Infrastructure
# 1       2658722536                                         Finance
# 2       4044163394                                  Infrastructure
# 3       5535865599                                  Infrastructure
# 4       3356802928                                 Port Operations
# ..             ...                                             ...
# 193     7940065082                                  Infrastructure
# 194     5157705612                                         Finance
# 195     9920755555                                 Port Operations
# 196     6638341389                                  Infrastructure
# 197     8114622230                          Information Technology
#
#     Identify which division you work in. - Other (please specify)  \
# 0                                                  NaN
# ...

# %%
id_vars = list(dataset_modified.columns)[ : 8]
id_vars
# Out:
# ['Respondent ID',
#  'Identify which division you work in. - Response',
#  'Identify which division you work in. - Other (please specify)',
#  'Which of the following best describes your position level? - Response',
#  'Which generation are you apart of? - Response',
#  'Please select the gender in which you identify. - Response',
#  'Which duration range best aligns with your tenure at your company? - Response',
#  'Which of the following best describes your employment type? - Response']

# %%
value_vars = list(dataset_modified.columns)[8 : ]

dataset_melted = dataset_modified.melt(id_vars=id_vars, 
                                       value_vars = value_vars, 
                                       var_name="Question + Subquestion", value_name="Answer")
dataset_melted
# Out:
#        Respondent ID Identify which division you work in. - Response  \
# 0         5379192392                                  Infrastructure
# 1         2658722536                                         Finance
# 2         4044163394                                  Infrastructure
# 3         5535865599                                  Infrastructure
# 4         3356802928                                 Port Operations
# ...              ...                                             ...
# 17023     7940065082                                  Infrastructure
# 17024     5157705612                                         Finance
# 17025     9920755555                                 Port Operations
# 17026     6638341389                                  Infrastructure
# 17027     8114622230                          Information Technology
#
#       Identify which division you work in. - Other (please specify)  \
# 0                                                    NaN
# ...

# %%
questions_import = pd.read_excel(pwd + "/Data - Survey Monkey Output Edited.xlsx", sheet_name="Question")
questions_import
# Out:
#      Raw Question Raw Subquestion       Question  Subquestion  \
# 0   Respondent ID             NaN  Respondent ID          NaN
# 1      Start Date             NaN     Start Date          NaN
# 2        End Date             NaN       End Date          NaN
# 3   Email Address             NaN  Email Address          NaN
# 4      First Name             NaN     First Name          NaN
# ..            ...             ...            ...          ...
# 95            NaN     Response 13    Question 29  Response 13
# 96            NaN     Response 14    Question 29  Response 14
# 97    Question 30      Response 1    Question 30   Response 1
# 98            NaN      Response 2    Question 30   Response 2
# 99            NaN      Response 3    Question 30   Response 3
#
#        Question + Subquestion
# 0               Respondent ID
# 1                  Start Date
# 2                    End Date
# 3               Email Address
# 4                  First Name
# ..                        ...
# ...

# %%
questions = questions_import.copy()
questions.drop(columns=["Raw Question", "Raw Subquestion", "Subquestion"], inplace=True)
questions.dropna(inplace=True)
questions.head(30)
# Out:
#                                              Question  \
# 0                                       Respondent ID
# 1                                          Start Date
# 2                                            End Date
# 3                                       Email Address
# 4                                          First Name
# 5                                           Last Name
# 6                                       Custom Data 1
# 7                Identify which division you work in.
# 8                Identify which division you work in.
# 9   Which of the following best describes your pos...
# 10                 Which generation are you apart of?
# 11    Please select the gender in which you identify.
# 12  Which duration range best aligns with your ten...
# 13  Which of the following best describes your emp...
# 14                                         Question 1
# 15                                         Question 2
# ...

# %%
dataset_merged = pd.merge(left=dataset_melted, right=questions
                          
                          ,how="left", left_on="Question + Subquestion",
                          right_on="Question + Subquestion"
                         )
print("Original Data", len(dataset_melted))
print("Merged Data", len(dataset_merged))
dataset_merged
# Out:
# Original Data 17028
# Merged Data 17028
#        Respondent ID Identify which division you work in. - Response  \
# 0         5379192392                                  Infrastructure
# 1         2658722536                                         Finance
# 2         4044163394                                  Infrastructure
# 3         5535865599                                  Infrastructure
# 4         3356802928                                 Port Operations
# ...              ...                                             ...
# 17023     7940065082                                  Infrastructure
# 17024     5157705612                                         Finance
# 17025     9920755555                                 Port Operations
# 17026     6638341389                                  Infrastructure
# 17027     8114622230                          Information Technology
#
#       Identify which division you work in. - Other (please specify)  \
# ...

# %%
respondents = dataset_merged[dataset_merged["Answer"].notna()]
respondents = respondents.groupby("Question")["Respondent ID"].nunique().reset_index()

# %%
respondents.rename(columns={"Respondent ID":"Respondents"}, inplace=True)
respondents
# Out:
#        Question  Respondents
# 0    Question 1          119
# 1   Question 10          198
# 2   Question 11          164
# 3   Question 12          114
# 4   Question 13          108
# 5   Question 14          105
# 6   Question 15          114
# 7   Question 16          117
# 8   Question 17          135
# 9   Question 18          109
# 10  Question 19          157
# 11   Question 2          118
# 12  Question 20          105
# 13  Question 21          127
# 14  Question 22          160
# 15  Question 23          120
# 16  Question 24          195
# 17  Question 25          198
# 18  Question 26          193
# 19  Question 27          153
# 20  Question 28          119
# 21  Question 29          198
# 22   Question 3          117
# 23  Question 30          182
# 24   Question 4          161
# 25   Question 5          194
# 26   Question 6          196
# 27   Question 7          162
# 28   Question 8          190
# 29   Question 9          188

# %%
dataset_merged_two = pd.merge(left=dataset_merged, right=respondents
#                               , how="left", left_on="Question", right_on="Question"
                             )
print("Original Data", len(dataset_merged))
print("Merged Data", len(dataset_merged_two))
dataset_merged_two
# Out:
# Original Data 17028
# Merged Data 17028
#        Respondent ID Identify which division you work in. - Response  \
# 0         5379192392                                  Infrastructure
# 1         2658722536                                         Finance
# 2         4044163394                                  Infrastructure
# 3         5535865599                                  Infrastructure
# 4         3356802928                                 Port Operations
# ...              ...                                             ...
# 17023     7940065082                                  Infrastructure
# 17024     5157705612                                         Finance
# 17025     9920755555                                 Port Operations
# 17026     6638341389                                  Infrastructure
# 17027     8114622230                          Information Technology
#
#       Identify which division you work in. - Other (please specify)  \
# ...

# %%
same_answer = dataset_merged
same_answer
# Out:
#        Respondent ID Identify which division you work in. - Response  \
# 0         5379192392                                  Infrastructure
# 1         2658722536                                         Finance
# 2         4044163394                                  Infrastructure
# 3         5535865599                                  Infrastructure
# 4         3356802928                                 Port Operations
# ...              ...                                             ...
# 17023     7940065082                                  Infrastructure
# 17024     5157705612                                         Finance
# 17025     9920755555                                 Port Operations
# 17026     6638341389                                  Infrastructure
# 17027     8114622230                          Information Technology
#
#       Identify which division you work in. - Other (please specify)  \
# 0                                                    NaN
# ...

# %%
same_answer = same_answer.groupby(
    ["Question + Subquestion", "Answer"])["Respondent ID"].nunique().reset_index()

same_answer.rename(columns={"Respondent ID":"Same Answer"}, inplace=True)
same_answer
# Out:
#       Question + Subquestion    Answer  Respondent ID
# 0      Question 1 - Response  Answer 1             14
# 1      Question 1 - Response  Answer 2             10
# 2      Question 1 - Response  Answer 3             13
# 3      Question 1 - Response  Answer 4             17
# 4      Question 1 - Response  Answer 5             22
# ..                       ...       ...            ...
# 683  Question 9 - Response 4  Answer 4             16
# 684  Question 9 - Response 4  Answer 5             13
# 685  Question 9 - Response 4  Answer 6             14
# 686  Question 9 - Response 4  Answer 7             12
# 687  Question 9 - Response 4  Answer 8             19
#
# [688 rows x 3 columns]

# %%
dataset_merged_three = pd.merge(left=dataset_merged_two, right=same_answer)
dataset_merged_three["Same Answer"].fillna(0, inplace=True)
print("Original Data", len(dataset_merged_two))
print("Merged Data", len(dataset_merged_three))
dataset_merged_three
# Out:
# Original Data 17028
# Merged Data 9664
#       Respondent ID Identify which division you work in. - Response  \
# 0        2658722536                                         Finance
# 1        2455127238                          Information Technology
# 2        1754220060                                         Finance
# 3        6285875694                                      Commercial
# 4        3968415666                                           Legal
# ...             ...                                             ...
# 9659     1636734067                          Information Technology
# 9660     2850296334                                  Infrastructure
# 9661     7447366993                          Information Technology
# 9662     2102054017                                         Finance
# 9663     1941311372                                  Infrastructure
#
#      Identify which division you work in. - Other (please specify)  \
# ...

# %%
output = dataset_merged_three.copy()
output.rename(columns={
    "Identify which division you work in. - Response":"Division Primary",
    "Identify which division you work in. - Other (please specify)":"Division Secondary",
    "Which of the following best describes your position level? - Response":"Position", 
    "Which generation are you apart of? - Response":"Generation", 
    "Please select the gender in which you identify. - Response":"Gender", 
    "Which duration range best aligns with your tenure at your company? - Response":"Tenure", 
    "Which of the following best describes your employment type? - Response":"Employment Type"}, inplace=True)
output
# Out:
#       Respondent ID        Division Primary Division Secondary  \
# 0        2658722536                 Finance                NaN
# 1        2455127238  Information Technology                NaN
# 2        1754220060                 Finance                NaN
# 3        6285875694              Commercial                NaN
# 4        3968415666                   Legal                NaN
# ...             ...                     ...                ...
# 9659     1636734067  Information Technology                NaN
# 9660     2850296334          Infrastructure                NaN
# 9661     7447366993  Information Technology                NaN
# 9662     2102054017                 Finance                NaN
# 9663     1941311372          Infrastructure                NaN
#
#              Position                             Generation  Gender  \
# 0               Staff                                    NaN     NaN
# ...

# %%
# output.to_excel(pwd + "/Final_Output.xlsx", index=False)

# %%
all_data.groupby('Product').count()['Count']

# %%
all_data = dataset_merged.copy()

# %%
all_data['Count'] = 1
all_data
# Out:
#        Respondent ID Identify which division you work in. - Response  \
# 0         5379192392                                  Infrastructure
# 1         2658722536                                         Finance
# 2         4044163394                                  Infrastructure
# 3         5535865599                                  Infrastructure
# 4         3356802928                                 Port Operations
# ...              ...                                             ...
# 17023     7940065082                                  Infrastructure
# 17024     5157705612                                         Finance
# 17025     9920755555                                 Port Operations
# 17026     6638341389                                  Infrastructure
# 17027     8114622230                          Information Technology
#
#       Identify which division you work in. - Other (please specify)  \
# 0                                                    NaN
# ...

# %%
all_data.groupby(["Answer"]).count()['Count']
# Out:
# Answer
# Answer 1    1183
# Answer 2    1205
# Answer 3    1173
# Answer 4    1213
# Answer 5    1276
# Answer 6    1228
# Answer 7    1213
# Answer 8    1173
# Name: Respondent ID, dtype: int64

# %%
all_data.groupby(["Answer",'Respondent ID']).count()['Count']
# Out:
# Answer    Respondent ID
# Answer 1  1001882880       2
#           1021794253       4
#           1220878407       3
#           1264208927       3
#           1321967343       2
#                           ..
# Answer 8  9920755555       1
#           9939738223       8
#           9945822370       7
#           9961006444       5
#           9983361274       6
# Name: Count, Length: 1583, dtype: int64
